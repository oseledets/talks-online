# %% [markdown]
# ## Title
#
# $c = a + b$
#
#  _Test_

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.plot(np.sinc(np.linspace(0, 1, 100)))

# %%
def fun(x):
    return
